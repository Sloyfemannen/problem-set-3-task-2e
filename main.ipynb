# %% [markdown]
# ### Problem set 3 task 2 e)

# %% [markdown]
# Håvard Zackarias Pettersen, FYS3120, spring 2026

# %% [markdown]
# We import packages:

# %%
import numpy as np
import scipy as sp
import matplotlib.pyplot as plt
